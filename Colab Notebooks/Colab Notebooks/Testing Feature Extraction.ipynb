# %% [markdown]
# Importing as per the suggestion of Google Colab tutorial

# %%
import itertools
import os

import matplotlib.pylab as plt
import numpy as np

import tensorflow as tf
import tensorflow_hub as hub

print("TF version:", tf.__version__)
print("Hub version:", hub.__version__)
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")
# Out:
# TF version: 2.6.0
# Hub version: 0.12.0
# GPU is NOT AVAILABLE

# %% [markdown]
# Importing based on using PyTorch

# %%
import tensorflow as tf
# !pip install torch
import torch as pt
print("Pytorch imported with version " + pt.__version__)

from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# ...
# Pytorch imported with version 1.9.0+cu111
# Mounted at /content/drive

# %%
model = tf.keras.Sequential([
    # Explicitly define the input shape so the model can be properly
    # loaded by the TFLiteConverter
    tf.keras.layers.InputLayer(input_shape=(128,128) + (3,)),
    hub.KerasLayer("https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_xl/feature_vector/2", trainable=True),
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(7,
                          kernel_regularizer=tf.keras.regularizers.l2(0.0001))
])

# %%
images = os.listdir('drive/MyDrive/Sodankyla_database-20211027T162911Z-002/Sodankyla_database/RAW/2014');
images
# Out:
# ['F_28Oct14_00.12.03.jpg',
#  'F_28Oct14_00.04.03.jpg',
#  'F_28Oct14_00.40.03.jpg',
#  'F_28Oct14_00.26.03.jpg',
#  'F_28Oct14_00.48.03.jpg',
#  'F_28Oct14_00.36.03.jpg',
#  'F_28Oct14_00.22.03.jpg',
#  'F_28Oct14_00.38.03.jpg',
#  'F_28Oct14_00.46.03.jpg',
#  'F_28Oct14_00.42.03.jpg',
#  'F_28Oct14_00.20.03.jpg',
#  'F_28Oct14_00.00.03.jpg',
#  'F_28Oct14_00.44.03.jpg',
#  'F_27Oct14_23.56.03.jpg',
#  'F_28Oct14_00.54.03.jpg',
#  'F_28Oct14_00.50.03.jpg',
#  'F_28Oct14_00.56.03.jpg',
#  'F_28Oct14_00.52.03.jpg',
#  'F_28Oct14_00.32.03.jpg',
#  'F_28Oct14_00.34.03.jpg',
#  'F_28Oct14_00.30.03.jpg',
#  'F_28Oct14_00.08.03.jpg',
#  'F_28Oct14_00.58.03.jpg',
#  'F_28Oct14_01.02.03.jpg',
#  'F_28Oct14_01.00.03.jpg',
#  'F_27Oct14_22.48.03.jpg',
#  'F_27Oct14_22.24.03.jpg',
#  'F_27Oct14_22.26.04.jpg',
#  'F_27Oct14_22.42.03.jpg',
#  'F_27Oct14_23.46.03.jpg',
#  'F_27Oct14_23.48.03.jpg',
#  'F_27Oct14_22.32.03.jpg',
#  'F_27Oct14_22.44.03.jpg',
#  'F_27Oct14_23.34.03.jpg',
# ...
